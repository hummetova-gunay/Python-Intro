# %% [markdown]
# # Variables
# Dəyişən — datanı saxlamaq üçün istifadə olunan qutudur.

# %%
# Dəyişən yaratmaq və çap etmək
# type() funksiyası ilə tipi yoxlamaq`  
a = 5
b = 6.5
c = True
2*a+3*b+5*c
# Out:
# 34.5

# %%
name = 'Gunay'
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(name)
# Out:
# str

# %%
type(c)
# Out:
# bool

# %% [markdown]
# ## Əsas Data Tipləri
#
# | Tip | Ad | Nümunə |
# |---|---|---|
# | `int` | Tam ədəd | `5`, `-3`, `100` |
# | `float` | Onluq ədəd | `3.14`, `-0.5` |
# | `str` | Mətn | `"salam"`, `'python'` |
# | `bool` | Məntiqi | `True`, `False` |

# %%
# int — tam ədədlər

# float — onluq ədədlər
# Out:
# 4
# 3.9

# %%
# Riyazi əməliyyatlar
a = 7
b = 2
print(a%2)
# Out:
# 1

# %%
# Out:
# str

# %%
# Out:
# bool

# %%
a.
# Out:
# bool

# %% [markdown]
# ## String

# %%
# String yaratmaq
name = 'Gunay'
# String əməliyyatları - böyük və kiçik hərf, uzunluq, ayırmaq və s
name.upper()
name.lower()
len(name)
# Out:
# 5

# %%
# f-string ilə formatlaşdırma
print(f'My name is {name}')
# Out:
# My name is Mehdi

# %%
# String indeksləmə
name[4]
# Out:
# 'y'

# %% [markdown]
# ## Bool

# %%
# bool dəyərlər: True , False

# Müqayisə əməliyyatları bool qaytarır
print(4>5)
# Out:
# False

# %% [markdown]
# ---
# ##  Suallar
#
# **Sual 1:** Aşağıdakı dəyişənlərin tiplərini `type()` funksiyası ilə yoxla. Nəticəni şərh et.
# ```python
# a = 5 / 2
# b = 5 // 2
# c = "3.14"
# d = True + 1
# ```
#
# ---
#
# **Sual 2:** Aşağıdakı kod işləyəcəkmi? Niyə? Necə düzəltmək olar?
# ```python
# yas = "25"
# print(yas + 5)
# ```
#
# ---
#
# **Sual 3:** `bool(0)`, `bool("")`, `bool([])` — bunların hamısı nə qaytarır? ML-də bunun əhəmiyyəti nədir?

# %%
yas = '25'
print(int(yas) + 5)
# Out:
# 30

# %%
yas = '25'
print(yas + 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 2
#       1 yas = '25'
# ----> 2 print(yas + 5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
'Gunay' + ' Hummatova'
# Out:
# 'Gunay Hummatova'
