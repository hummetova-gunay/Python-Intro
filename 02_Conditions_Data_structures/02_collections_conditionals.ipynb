# %% [markdown]
# # Session 2: Collections & Conditionals
#
# Ötən dərsdə öyrəndiklərimiz:
# - Dəyişənlər və mənimsətmə
# - Əsas tiplər: `int`, `float`, `str`, `bool`
# - `type()`, f-string, string metodları
#
# Bu dərsin mövzuları:
# 1. **List**
# 2. **Tuple**
# 3. **Dictionary**
# 4. **if / elif / else**

# %% [markdown]
# ---
# ## 1. List (Siyahı)
#
# List — bir neçə dəyəri **ardıcıl** saxlayan strukturdur.
# Kvadrat mötərizə `[ ]` ilə yazılır.

# %%
# Sadə list yaratmaq
num_lst = [10,20,30,40,50]
num_lst
# Out:
# [10, 20, 30, 40, 50]

# %%
# İndekslə element almaq (0-dan başlayır)
num_lst[-1] + num_lst[2]
# Out:
# 80

# %%
# Slicing — bir hissəsini almaq
num_lst[:-3]
# Out:
# [10, 20]

# %%
# List metodları
# append, remove, len, sorted
print(f'Original list: {num_lst}')
num_lst.append(60)
print(f'After adding a new item: {num_lst}')
# Out:
# Original list: [10, 20, 30, 40, 50]
# After adding a new item: [10, 20, 30, 40, 50, 60]

# %%
num_lst.remove(60)
print(f'After removing: {num_lst}')
# Out:
# After removing: [10, 20, 30, 40, 50]

# %%
len(num_lst)
# Out:
# 5

# %%
sorted(num_lst, reverse=True)
# Out:
# [50, 40, 30, 20, 10]

# %%
num_lst
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# ---
# ## 2. Tuple
#
# Tuple list-ə oxşayır, amma tuple daxilində olan elementlər dəyişdirilə bilməz (immutable).
# Yuvarlaq mötərizə `( )` ilə yazılır.

# %%
# Tuple yaratmaq

# %%
# İndeksləmə eyni işləyir

# %%
# Tuple dəyişdirilə bilməz — bu xəta verəcək:

# %% [markdown]
# ---
# ## 3. Dictionary (Lüğət)
#
# Dictionary — **açar : dəyər** cütlərindən ibarət strukturdur.
# Fiqurlu mötərizə `{ }` ilə yazılır.

# %%
# Dictionary yaratmaq

# %%
# Dəyərə açarla çatmaq

# %%
# Bütün açarlar və dəyərlər

# %% [markdown]
# ---
# ## 4. if / elif / else — Şərt Operatoru
#
# Proqram müxtəlif şərtlərə görə fərqli addımlar ata bilər.

# %%
if 3>2:
    print('Hello')
else:
    print('Hi')
# Out:
# Hello

# %%
if len('Cat')>len('Dog'):
    print('Cat is longer')
elif len('Cat') == len('Dog'):
    print('They are equal')
else:
    print('Dog is longer')
# Out:
# They are equal

# %%
# and / or ilə mürəkkəb şərtlər

# %%
num_lst
# Out:
# [10, 20, 30, 40, 50]

# %%
# in operatoru — listdə var ya yox?
if 70 in num_lst:
    print('Yes')
else:
    print('No')
# Out:
# No

# %% [markdown]
# ---
# ##  Suallar
#
# **Sual 1:** Aşağıdakı list-i yaradıb cavab ver:
# ```python
# qiymetler = [4, 7, 2, 9, 1, 5, 8]
# ```
# - Ən böyük elementi tap
# - Ən kiçik elementi tap
# - Siyahını çevirərək (reversed) çap et
# - İlk 4 elementi ayrıca çap et
#
# ---
#
# **Sual 2:** Aşağıdakı dictionary-ni doldur və hər dəyərə çat:
# ```python
# model_info = {
#     'ad': ...,          # modelin adı (string)
#     'dəqiqlik': ...,    # 0 ilə 1 arasında (float)
#     'parametr_sayi': ...  # tam ədəd (int)
# }
# ```
# Sonra f-string ilə belə bir cümlə çap et:
# `"[ad] modelinin dəqiqliyi [dəqiqlik]% təşkil edir."`
#
# ---
#
# **Sual 3:** `dəqiqlik` dəyərinə görə modeli qiymətləndir:
# - 0.90 və yuxarı → `"Production-a hazırdır"`
# - 0.75 – 0.89 → `"Daha çox train lazımdır"`
# - 0.75-dən aşağı → `"Model zəifdir, yenidən dizayn et"`

# %%
# Sual 1

# %%
# Sual 2

# %%
# Sual 3

# %%
# Sual 3
