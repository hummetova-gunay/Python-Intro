# %%
# slicing
a = "AI in Business"
print(a[0:2])
# Out:
# AI

# %%
print(a[2:])
# Out:
#  in Business

# %%
# modify strings
b = "Khazar University"
print(b.upper())
# Out:
# KHAZAR UNIVERSITY

# %%
print(b.lower())
# Out:
# khazar university

# %%
# remove whitespace
c= "    Economics and Management   "
print(c.strip())
# Out:
# Economics and Management

# %%
# replace strings
name = "Gulnare"
print(name.replace("e", ""))
# Out:
# Gulnar

# %%
# split string
full_name = "Gunay Hummatova"
print(full_name.split()[0])
# Out:
# Gunay

# %%
# concatenate strings
name = "Gunay"
surname = "Hummatova"
full_name = name+' '+surname
print(full_name)
# Out:
# Gunay Hummatova

# %% [markdown]
# # Exercises

# %%
# Create a variable called student_name

# %%
# Print the length of the string

# %%
# the first and the last character

# %%
# Print: the first 3 and then the last 4 characters

# %%
# Convert the string to uppercase.

# %%
sentence = "I like Java"
# Replace "Java" with "Python"

# %%
sentence = "Python is a powerful programming language"
# Check if "Python" exists in the sentence.
# Out:
# Found 'Python' in the sentence.
