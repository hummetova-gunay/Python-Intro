# %%
# creating dictionaries
student = {
    "name": "Ali",
    "age": 21,
    "major": "Computer Science",
    # id:1
}

print(student)

# %%
teacher = {
    'Name': ['Gunay','Gulnar', 'Humay'] 
}

# %%
for i in teacher['Name']:
    print(i + ' Teacher')

# %%
# accessing values
student = {
    "name": "Ali",
    "age": 21,
    "major": "Computer Science"
}

print(student["name"])
print(student["age"])

# %%
# adding a new key
student = {
    "name": "Ali",
    "age": 21
}

student["city"] = "Baku"

print(student['city'])

# %%
# modifiying values
student = {
    "name": "Ali",
    "age": 21
}

student["age"] = 22
print(student)

# %%
# throw an error when there is no such key
print(student['city'])

# %%
# .get() avoids this error
student = {
    "name": "Ali",
    "age": 21
}
student['name']
print(student.get("name"))
print(student.get("city"))

# %%
# looping through keys
student = {
    "name": "Ali",
    "age": 21,
    "city": "Baku"
}

for key in student:
    print(key)

# %%
student.keys()

# %%
student.values()

# %%
# loop through values
for value in student.values():
    print(value)

# %%
student.items()

# %%
# loop through keys and values
for key, value in student.items():
    print(key, value)

# %%
# length
student_dict = {
    "name": ["Ali", 'Gunay'],
    "age": [21,22],
    "city": ["Baku", 'Baku']
}

print(len(student))

# %%
import pandas as pd

# %%
df = pd.DataFrame(student_dict)

# %%
df.to_csv('test.csv')

# %%
# mix of data types
student = {
    "name": "Ali",
    "scores": [85, 90, 88]
}

print(student["scores"])
print(min(student["scores"]))

# %%
list_1 = [[1,2], [3,4], [4,5]]

# %%
len(list_1)

# %%
# nested dictionaries
students = {
    "student1": {"name": "Ali", "age": 21},
    "student2": {"name": "Leyla", "age": 22}
}

print(students["student2"]["age"])

# %%
# 1.Create a dictionary storing 3 countries and their capitals.

# 2.Write a function that prints all keys in a dictionary.

# 3.Write a function that returns the sum of all values in a dictionary.

# 4.Write a function that finds the key with the highest value.

# 5.Count how many times each letter appears in a word using a dictionary.

# %%
my_dict = {
    'scores':[90,92, 97, 100]
}

# %%
def find_max(my_dict):
    for key in my_dict.keys():
        return max(my_dict[key])

# %%
find_max(my_dict)
# Out:
# 100
